# %% [markdown]
# <a href="https://colab.research.google.com/github/JG-Park/HAaddons/blob/main/%EA%B8%B0%EC%B4%88%EB%AC%B8%EB%B2%95_231226.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 1
# - 멀티캠퍼스 첫 수업

# %% [markdown]
# ## Chapter 1. 구글 코랩 수업
# - ₩₩12₩12

# %%
a = 1
b = 2

# %% [markdown]
# # Section 2
# - 아무 말

# %%
1 == 1
# Out:
# True

# %% [markdown]
# ## Chapter 2.

# %%
1

# %% [markdown]
# # Section 3 ~

# %% [markdown]
# ## Chapter 3. 아무 말

# %% [markdown]
# (1) 이건 1번

# %%
1+1
# Out:
# 2
